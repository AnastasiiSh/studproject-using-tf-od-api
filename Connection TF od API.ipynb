# %% [markdown]
# **Выполните данные команды, чтобы подключить Tensorfliw object detection API**
#
# 👉🏿  TensorFlow object detection API (https://github.com/tensorflow/models/tree/master/research/object_detection)
#
# 👉🏿 Изображения и разметка
#  (https://drive.google.com/open?id=1UU98uLVcnsgp2NpHn3UV8ksO4ggnd-xP)

# %%
# !apt-get install -y -qq protobuf-compiler python-pil python-lxml
# сбрасываем tf до версии 1.*, так как API не интегрирован еще до версий 2.*
# !pip install tensorflow==1.15.2 
# !pip install tensorflow-gpu==1.15.2
# !pip install Cython

# %%
# добавляем доступ к данным из гугл диска
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd '/content/drive/My Drive/projects/waste_sorting'
# Out:
# /content/drive/My Drive/projects/waste_sorting

# %%
# !git clone --quiet --single-branch --branch r1.13.0 https://github.com/tensorflow/models.git
# Out:
# ^C

# %%
# %cd /content/drive/My Drive/projects/waste_sorting/models/research/
# !protoc object_detection/protos/*.proto --python_out=.
# Out:
# /content/drive/My Drive/projects/waste_sorting/models/research

# %%
# !protoc object_detection/protos/*.proto --python_out=.

# %%
import os
os.environ['PYTHONPATH'] += ':/content/drive/My Drive/projects/waste_sorting/models/research/:/content/drive/My Drive/projects/waste_sorting/models/research/slim'

# %%
# !python setup.py build
# !python setup.py install
# Out:
# running build
# running build_py
# creating build
# creating build/lib
# creating build/lib/object_detection
# copying object_detection/__init__.py -> build/lib/object_detection
# copying object_detection/eval_util.py -> build/lib/object_detection
# copying object_detection/eval_util_test.py -> build/lib/object_detection
# copying object_detection/export_inference_graph.py -> build/lib/object_detection
# copying object_detection/export_tflite_ssd_graph.py -> build/lib/object_detection
# copying object_detection/export_tflite_ssd_graph_lib.py -> build/lib/object_detection
# copying object_detection/export_tflite_ssd_graph_lib_test.py -> build/lib/object_detection
# copying object_detection/exporter.py -> build/lib/object_detection
# copying object_detection/exporter_test.py -> build/lib/object_detection
# copying object_detection/inputs.py -> build/lib/object_detection
# copying object_detection/inputs_test.py -> build/lib/object_detection
# ...

# %%
# запускаем для тестирования установки
# %run object_detection/builders/model_builder_test.py
# Out:
# Running tests under Python 3.6.9: /usr/bin/python3
# [ RUN      ] ModelBuilderTest.test_create_embedded_ssd_mobilenet_v1_model_from_config
# [       OK ] ModelBuilderTest.test_create_embedded_ssd_mobilenet_v1_model_from_config
# [ RUN      ] ModelBuilderTest.test_create_faster_rcnn_inception_resnet_v2_model_from_config
# [       OK ] ModelBuilderTest.test_create_faster_rcnn_inception_resnet_v2_model_from_config
# [ RUN      ] ModelBuilderTest.test_create_faster_rcnn_inception_v2_model_from_config
# [       OK ] ModelBuilderTest.test_create_faster_rcnn_inception_v2_model_from_config
# [ RUN      ] ModelBuilderTest.test_create_faster_rcnn_model_from_config_with_example_miner
# [       OK ] ModelBuilderTest.test_create_faster_rcnn_model_from_config_with_example_miner
# [ RUN      ] ModelBuilderTest.test_create_faster_rcnn_nas_model_from_config
# [       OK ] ModelBuilderTest.test_create_faster_rcnn_nas_model_from_config
# ...
